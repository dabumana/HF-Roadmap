# %% [markdown]
# <a href="https://colab.research.google.com/github/dabumana/HF-Roadmap/blob/main/Agents-Course/unit2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Frameworks for LLM Agents**

# %% [markdown]
# Common frameworks used for LLM agent construction.

# %%
# !pip install smolagents
# !pip install llama-index
# !pip install langgraph
# Out:
# Requirement already satisfied: smolagents in /usr/local/lib/python3.11/dist-packages (1.16.1)
# Requirement already satisfied: huggingface-hub>=0.31.2 in /usr/local/lib/python3.11/dist-packages (from smolagents) (0.31.2)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from smolagents) (2.32.3)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.11/dist-packages (from smolagents) (13.9.4)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.11/dist-packages (from smolagents) (11.2.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from smolagents) (1.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.4->smolagents) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->smolagents) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->smolagents) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: llama-index in /usr/local/lib/python3.11/dist-packages (0.12.36)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.36 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.12.36)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.6.11)
# Requirement already satisfied: llama-index-llms-openai<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.40)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.78.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (3.11.15)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (2.1.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (2025.3.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (2.11.4)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from llama-index-core<0.13,>=0.12.36->llama-index) (1.17.2)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in /usr/local/lib/python3.11/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.19)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (5.5.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.22)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (8.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index) (1.20.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index) (3.1.6)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index) (4.3.8)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.7)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from llama-cloud<0.2.0,>=0.1.13->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.4.26)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.36->llama-index) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.36->llama-index) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->llama-index-core<0.13,>=0.12.36->llama-index) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.36->llama-index) (0.16.0)
# Requirement already satisfied: llama-cloud-services>=0.6.22 in /usr/local/lib/python3.11/dist-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.22)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.36->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.36->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.36->llama-index) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.36->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.36->llama-index) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.36->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.36->llama-index) (3.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from llama-cloud-services>=0.6.22->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.11/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.36->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.11/dist-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index) (3.0.2)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.11/dist-packages (0.4.5)
# Requirement already satisfied: langchain-core>=0.1 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.3.59)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.26 in /usr/local/lib/python3.11/dist-packages (from langgraph) (2.0.26)
# Requirement already satisfied: langgraph-prebuilt>=0.1.8 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.1.8)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.1.69)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langgraph) (2.11.4)
# Requirement already satisfied: xxhash<4.0.0,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (3.5.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core>=0.1->langgraph) (4.13.2)
# Requirement already satisfied: ormsgpack<2.0.0,>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from langgraph-checkpoint<3.0.0,>=2.0.26->langgraph) (1.9.1)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from langgraph-sdk>=0.1.42->langgraph) (3.10.18)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->langgraph) (0.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core>=0.1->langgraph) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core>=0.1->langgraph) (2.4.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk>=0.1.42->langgraph) (1.3.1)

# %%
from google.colab import userdata as ud
from huggingface_hub import login

env_token = ud.get('HF_TOKEN')
login(env_token)

# %%
# !pip install duckduckgo_search
# !pip install beautifulsoup4
# !pip install html5lib
# Out:
# Requirement already satisfied: duckduckgo_search in /usr/local/lib/python3.11/dist-packages (8.0.2)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from duckduckgo_search) (8.2.0)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from duckduckgo_search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from duckduckgo_search) (5.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.11/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib) (0.5.1)

# %% [markdown]
# **`smolagents`** - use case

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model = InferenceClientModel())
agent.run("Elaborate a guide around bin 9, include secure encrypted communications using p2p")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Elaborate a guide around bin 9, include secure encrypted communications using p2p                               │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   bin9_info = web_search(query="what is bin 9")
#   print(bin9_info)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Cracking the Code: Understanding BIN Ranges in Bank Identification
# ...](https://fastercapital.com/content/Cracking-the-Code--Understanding-BIN-Ranges-in-Bank-Identification-Numbers.h
# tml)
# 4. Understanding the Structure of BIN Ranges. When it comes to deciphering the complex world of Bank Identification
# Numbers (BINs), understanding the structure of BIN ranges is a crucial step. BIN ranges are the series of numbers
# that make up the first six digits of a credit or debit card, providing valuable information about the issuing
# institution and the card's attributes.
#
# [Bank Identification Number Guide & BIN List - Chargeback
# Gurus](https://www.chargebackgurus.com/blog/bank-identification-number)
# A BIN may also be referred to as an Issuer Identification Number (IIN), given that banks are not the only
# institutions that issue payment cards. These numbers provide information that allows merchants to easily derive
# information about where a card came from based on the card number alone. Each credit card network has a range of
# BINs associated ...
#
# [The basics of BINs: Understanding different
# types](https://reap.global/blog/the-basics-of-bins-understanding-different-types)
# A retail BIN is assigned to cards issued for personal use, while a commercial BIN is used for cards issued for
# business purposes. While each type of BIN can carry different features and benefits suitable for its intended use,
# there is not a whole lot of difference between retail vs commercial BIN. The only differences you should be aware
# of are:
#
# [What Is a Bank Identification Number (BIN)? | Capital
# One](https://www.capitalone.com/learn-grow/money-management/bank-identification-number/)
# The BIN is either embossed or printed on the front or back of a credit card. Depending on your card, the BIN may be
# the first six or eight digits. Here's a hypothetical example of the different digits that make up a card number:
# 4003 4411 2222 3333. In this example, 400344 is the six-digit BIN. The first digit is the MII, indicating the ...
#
# [What is a BIN number? - Checkout.com](https://www.checkout.com/blog/bin-number-explained)
# What is a BIN number? A Bank Identification Number (BIN) is the first six to eight digits of the Primary Account
# Number (PAN), the long number on a credit, debit, or prepaid card. A BIN essentially tells the merchant which bank
# or other financial institution issued the card.
#
# [Understanding Bank Identification Numbers (BINs) |
# Primer](https://primer.io/blog/decoding-bank-identification-numbers-bins-and-what-they-mean-for-merchants)
# A Bank Identification Number (BIN) is a sequence of numbers on a payment card that is part of the Primary Account
# Number (PAN). These digits are not random; they provide specific information about the card. The BIN identifies the
# issuing bank or financial institution, the type of card, and the card scheme (such as Visa or MasterCard).
#
# [What is a BIN range? Definition, structure, and uses](https://onemoneyway.com/en/blog/bin-ranges/)
# BIN Recognition: The system reads the first few digits (the BIN) and verifies its range. Issuer Identification:
# Based on the BIN, the system recognizes the issuing bank and card type. Transaction Approval or Denial: If the BIN
# matches expected patterns for that type of card, the transaction can proceed. If not, the system may flag it as
# suspicious.
#
# [What is a BIN in Payment Processing -
# clearlypayments.com](https://www.clearlypayments.com/blog/what-is-a-bin-in-payment-processing/)
# The role of the BIN extends beyond simply identifying the card issuer; it affects various aspects of the payment
# process: Transaction Routing: When a customer makes a purchase using a card, the payment processor uses the BIN to
# route the transaction to the right financial institution.This routing allows the processor to request authorization
# for the transaction from the issuing bank, which ...
#
# [What is a BIN? - Chargeblast](https://www.chargeblast.com/blog/bank-identification-numbers/)
# The BIN, also referred to as the bank identification code, is a systematic numbering scheme contrived to ascertain
# the specific institution responsible for issuing a given credit card or any other form of bank card, along with
# categorizing the nature of the institution. Essentially, it operates as the bank's distinctive emblem; each bank
# that ...
#
# [BIN Checker: Understanding Bank Identification
# Numbers](https://mypaymentsavvy.com/bin-checker-understanding-bank-identification-numbers/)
# A Bank Identification Number (BIN) is the first four or six numbers found on any debit or credit card. Essentially,
# this set of digits specifies the financial institution that issued a payment card. Every BIN number can be checked
# to prevent fraud and ensure the protection of both merchants and consumers when shopping.
#
# Out: None
# [Step 1: Duration 1.10 seconds| Input tokens: 2,055 | Output tokens: 86]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   p2p_encryption_info = web_search(query="secure encrypted communications using P2P")
#   print(p2p_encryption_info)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [P2P encryption: Pros and cons of point-to-point
# encryption](https://www.techtarget.com/searchsecurity/tip/P2P-encryption-Pros-and-cons-of-point-to-point-encryption
# )
# By deploying P2P encryption, the retailer can limit the scope of exposure credit card numbers operate under within
# the merchandizing environment.For example, by deploying a point of sale (POS) system that uses encrypting card
# scanners and is supported by a back-end system in the home office that supports point-to-point encryption, the
# entire store network is taken out of the loop.
#
# [How to Secure Your P2P Network: A Comprehensive Cybersecurity Guide](https://toxigon.com/cybersecurity-and-p2p)
# Let's look at a real-world example to illustrate how these principles can be applied. Imagine a file-sharing P2P
# network used by a group of friends to share documents and media files. Here's how they could secure their network:
# Encryption: Use AES encryption to protect data in transit. Authentication: Implement 2FA for all users.
#
# [Security in P2P Networks - Comparitech](https://www.comparitech.com/net-admin/p2p-network-security/)
# Cryptographic Techniques for Secure Communication. Cryptography plays a vital role in securing P2P networks by
# providing multiple layers of protection. The use of encryption ensures that data transferred between peers remains
# confidential, protecting it from eavesdropping and MitM attacks.
#
# [Point-to-Point Encryption (P2PE) Guide - ACI Worldwide](https://www.aciworldwide.com/p2p-encryption)
# In a P2P transaction, the data is fully encrypted from the time a customer enters their information to the point
# where it is received by the payment processor. While the concept of encryption has been around for centuries, P2P
# encryption is a specific form of hardware encryption that occurs via a secured, fit-for-use payments device.
#
# [What Is P2P Encryption - Robots.net](https://robots.net/fintech/what-is-p2p-encryption/)
# P2P encryption combines the principles of encryption and peer-to-peer networks to enable secure communication and
# file sharing between peers. By distributing the encryption and decryption responsibilities among participating
# peers, P2P encryption enhances security and privacy while reducing reliance on centralized authorities.
#
# [Securing Your Data Stream with P2P Encryption - Nordic
# APIs](https://nordicapis.com/securing-your-datastream-with-p2p-encryption/)
# Another form of encryption is the Symmetric-key methodology, which utilizes the same two keys to both encrypt and
# decrypt. This method is secure for local use (such as encrypting password databases on a root server), but should
# not be used over a network in its plain form without encrypting the session key or data stream using a secondary
# assymetric encrypted protocol.
#
# [P2P in Enterprise: Benefits, Use Cases & Deployment Guide -
# Comparitech](https://www.comparitech.com/net-admin/p2p-in-enterprise/)
# P2P networks can implement end-to-end encryption to secure data as it travels between peers. By encrypting
# communications, businesses ensure that sensitive information cannot be intercepted or accessed by unauthorized
# parties. ... GitHub implemented end-to-end encryption in its P2P communication system. This ensured that data
# exchanged between ...
#
# [Secure Peer-to-Peer Communication -
# Ditto](https://docs.ditto.live/best-practices/secure-peer-to-peer-communication)
# Below are key best practices: End-to-End Encryption: Ensure all data exchanged between peers is encrypted, using
# protocols like TLS or custom end-to-end encryption schemes.; Mutual Authentication: Implement strong authentication
# using OAuth, JWT, or cryptographic handshakes to verify both peers.; Secure Transport Layers: Use secure transports
# such as WebSockets or Bluetooth LE with encrypted ...
#
# [GitHub - noomorph/p2p: Browser-based end-to-end encrypted message ...](https://github.com/noomorph/p2p)
# A sleek, browser-based secure message exchange application that enables end-to-end encrypted communication between
# peers. This lightweight tool allows users to easily encrypt and decrypt messages using public-key cryptography, all
# while keeping your sensitive data secure.
#
# [P2P | Canopy Network Docs](https://canopy-network.gitbook.io/docs/welcome-to-canopy/how-does-canopy-work/p2p)
# It implements a secure, multiplexed, and encrypted communication system between network nodes that enables both
# efficient gossip and point-to-point transmission. ... Message Encryption: Use the derived keys along with the
# ChaCha20-Poly1305 Authenticated ... Due to the requirements of NestBFT's linear communication complexity — the P2P
# module ...
#
# Out: None
# [Step 2: Duration 12.43 seconds| Input tokens: 5,281 | Output tokens: 312]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   guide = """
#   # Guide: BIN 9 and Secure Encrypted Communications Using P2P
#
#   ## 1. Introduction to BIN 9
#   BIN 9 is a theoretical BIN range, as standard BIN numbers follow a specific format and bin 9 is not a defined
#   prefix. BINs (Bank Identification Numbers) are the first 4-6 digits of a credit or debit card, identifying the
#   issuing institution. For the purpose of this guide, we will treat BIN 9 as a placeholder for a specific range
#   of BINs (e.g., 900000-999999).
#
#   ## 2. Importance of Secure Encrypted Communications
#   In today’s digital age, securing data transmissions is crucial, especially for financial transactions that may
#   use BINs for identification. Encrypted communications help protect sensitive information from unauthorized
#   access and eavesdropping. Secure P2P networks provide a decentralized method of sharing information securely,
#   making them ideal for applications such as secure file sharing and financial transactions.
#
#   ## 3. Peer-to-Peer (P2P) Technology Overview
#   Peer-to-Peer (P2P) technology allows for direct communication between networked devices (peers), enabling
#   distributed data storage and sharing. In a P2P network, each participant can act as both a client and a server,
#   distributing the load and improving efficiency. P2P networks are widely used in file sharing, media streaming,
#   and blockchain technologies.
#
#   ## 4. Setting Up Secure Encrypted P2P Communications
#   To set up secure P2P communications, follow these steps:
#
#   ### 4. 1 Choose a Reliable P2P Framework
#   Select a robust P2P framework that supports encryption. Some popular frameworks include:
#   - **WebRTC**: Ideal for real-time communication applications.
#   - **BitTorrent**: A well-established P2P framework for file sharing.
#   - **Ditto**: A framework for securing peer-to-peer communication.
#
#   ### 4. 2 Implement End-to-End Encryption
#   Use protocols like TLS or custom end-to-end encryption schemes to protect data in transit. End-to-end
#   encryption ensures that only the communicating parties can read the data.
#
#   ### 4. 3 Secure Transport Layers
#   Use secure transports such as WebSockets or Bluetooth LE with encrypted communication channels.
#
#   ### 4. 4 Implement Mutual Authentication
#   Use strong authentication methods to verify both peers. Options include OAuth, JWT, or cryptographic
#   handshakes.
#
#   ### 4. 5 Use Public-Key Cryptography
#   Leverage public-key cryptography for secure key exchange and data encryption. Tools like SSH and PGP use
#   public-key cryptography to ensure secure communications.
#
#   ### 4. 6 Regularly Update and Patch
#   Keep your P2P framework and encryption libraries up to date to protect against vulnerabilities.
#
#   ## 5. Best Practices for P2P Encryption
#   - **End-to-End Encryption**: Ensure all data exchanged between peers is encrypted.
#   - **Mutual Authentication**: Verify both peers using strong authentication methods.
#   - **Secure Transport Layers**: Use encrypted communication channels.
#   - **Regular Updates**: Keep your software and libraries up to date.
#   - **Data Integrity Checks**: Use cryptographic hashing to ensure data integrity.
#
#   ## 6. Tools and Libraries for P2P Encryption
#   - **WebRTC**: Real-time communication framework with built-in encryption.
#   - **OpenSSL**: Comprehensive cryptography library with support for P2P encryption.
#   - **PyCryptodome**: Python library for implementing various cryptographic algorithms.
#   - **Crypto**: Comprehensive cryptographic library for Node.js.
#   - **libsodium**: Library for secure communications and P2P encryption.
#
#   By following this guide, you can set up secure, encrypted P2P communications similar to those used with
#   financial transactions involving BINs. This setup will help protect sensitive information and ensure secure
#   data sharing between peers.
#   """
#
#   final_answer(guide)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer:
# # Guide: BIN 9 and Secure Encrypted Communications Using P2P
#
# ## 1. Introduction to BIN 9
# BIN 9 is a theoretical BIN range, as standard BIN numbers follow a specific format and bin 9 is not a defined
# prefix. BINs (Bank Identification Numbers) are the first 4-6 digits of a credit or debit card, identifying the
# issuing institution. For the purpose of this guide, we will treat BIN 9 as a placeholder for a specific range of
# BINs (e.g., 900000-999999).
#
# ## 2. Importance of Secure Encrypted Communications
# In today’s digital age, securing data transmissions is crucial, especially for financial transactions that may use
# BINs for identification. Encrypted communications help protect sensitive information from unauthorized access and
# eavesdropping. Secure P2P networks provide a decentralized method of sharing information securely, making them
# ideal for applications such as secure file sharing and financial transactions.
#
# ## 3. Peer-to-Peer (P2P) Technology Overview
# Peer-to-Peer (P2P) technology allows for direct communication between networked devices (peers), enabling
# distributed data storage and sharing. In a P2P network, each participant can act as both a client and a server,
# distributing the load and improving efficiency. P2P networks are widely used in file sharing, media streaming, and
# blockchain technologies.
#
# ## 4. Setting Up Secure Encrypted P2P Communications
# To set up secure P2P communications, follow these steps:
#
# ### 4. 1 Choose a Reliable P2P Framework
# Select a robust P2P framework that supports encryption. Some popular frameworks include:
# - **WebRTC**: Ideal for real-time communication applications.
# - **BitTorrent**: A well-established P2P framework for file sharing.
# - **Ditto**: A framework for securing peer-to-peer communication.
#
# ### 4. 2 Implement End-to-End Encryption
# Use protocols like TLS or custom end-to-end encryption schemes to protect data in transit. End-to-end encryption
# ensures that only the communicating parties can read the data.
#
# ### 4. 3 Secure Transport Layers
# Use secure transports such as WebSockets or Bluetooth LE with encrypted communication channels.
#
# ### 4. 4 Implement Mutual Authentication
# Use strong authentication methods to verify both peers. Options include OAuth, JWT, or cryptographic handshakes.
#
# ### 4. 5 Use Public-Key Cryptography
# Leverage public-key cryptography for secure key exchange and data encryption. Tools like SSH and PGP use public-key
# cryptography to ensure secure communications.
#
# ### 4. 6 Regularly Update and Patch
# Keep your P2P framework and encryption libraries up to date to protect against vulnerabilities.
#
# ## 5. Best Practices for P2P Encryption
# - **End-to-End Encryption**: Ensure all data exchanged between peers is encrypted.
# - **Mutual Authentication**: Verify both peers using strong authentication methods.
# - **Secure Transport Layers**: Use encrypted communication channels.
# - **Regular Updates**: Keep your software and libraries up to date.
# - **Data Integrity Checks**: Use cryptographic hashing to ensure data integrity.
#
# ## 6. Tools and Libraries for P2P Encryption
# - **WebRTC**: Real-time communication framework with built-in encryption.
# - **OpenSSL**: Comprehensive cryptography library with support for P2P encryption.
# - **PyCryptodome**: Python library for implementing various cryptographic algorithms.
# - **Crypto**: Comprehensive cryptographic library for Node.js.
# - **libsodium**: Library for secure communications and P2P encryption.
#
# By following this guide, you can set up secure, encrypted P2P communications similar to those used with financial
# transactions involving BINs. This setup will help protect sensitive information and ensure secure data sharing
# between peers.
# [Step 3: Duration 42.25 seconds| Input tokens: 9,764 | Output tokens: 1,216]
# '\n# Guide: BIN 9 and Secure Encrypted Communications Using P2P\n\n## 1. Introduction to BIN 9\nBIN 9 is a theoretical BIN range, as standard BIN numbers follow a specific format and bin 9 is not a defined prefix. BINs (Bank Identification Numbers) are the first 4-6 digits of a credit or debit card, identifying the issuing institution. For the purpose of this guide, we will treat BIN 9 as a placeholder for a specific range of BINs (e.g., 900000-999999).\n\n## 2. Importance of Secure Encrypted Communications\nIn today’s digital age, securing data transmissions is crucial, especially for financial transactions that may use BINs for identification. Encrypted communications help protect sensitive information from unauthorized access and eavesdropping. Secure P2P networks provide a decentralized method of sharing information securely, making them ideal for applications such as secure file sharing and financial transactions.\n\n## 3. Peer-to-Peer (P2P) Technology Overview\nPeer-to-Peer (P2P) technology allows for direct communication between networked devices (peers), enabling distributed data storage and sharing. In a P2P network, each participant can act as both a client and a server, distributing the load and improving efficiency. P2P networks are widely used in file sharing, media streaming, and blockchain technologies.\n\n## 4. Setting Up Secure Encrypted P2P Communications\nTo set up secure P2P communications, follow these steps:\n\n### 4. 1 Choose a Reliable P2P Framework\nSelect a robust P2P framework that supports encryption. Some popular frameworks include:\n- **WebRTC**: Ideal for real-time communication applications.\n- **BitTorrent**: A well-established P2P framework for file sharing.\n- **Ditto**: A framework for securing peer-to-peer communication.\n\n### 4. 2 Implement End-to-End Encryption\nUse protocols like TLS or custom end-to-end encryption schemes to protect data in transit. End-to-end encryption ensures that only the communicating parties can read the data.\n\n### 4. 3 Secure Transport Layers\nUse secure transports such as WebSockets or Bluetooth LE with encrypted communication channels.\n\n### 4. 4 Implement Mutual Authentication\nUse strong authentication methods to verify both peers. Options include OAuth, JWT, or cryptographic handshakes.\n\n### 4. 5 Use Public-Key Cryptography\nLeverage public-key cryptography for secure key exchange and data encryption. Tools like SSH and PGP use public-key cryptography to ensure secure communications.\n\n### 4. 6 Regularly Update and Patch\nKeep your P2P framework and encryption libraries up to date to protect against vulnerabilities.\n\n## 5. Best Practices for P2P Encryption\n- **End-to-End Encryption**: Ensure all data exchanged between peers is encrypted.\n- **Mutual Authentication**: Verify both peers using strong authentication methods.\n- **Secure Transport Layers**: Use encrypted communication channels.\n- **Regular Updates**: Keep your software and libraries up to date.\n- **Data Integrity Checks**: Use cryptographic hashing to ensure data integrity.\n\n## 6. Tools and Libraries for P2P Encryption\n- **WebRTC**: Real-time communication framework with built-in encryption.\n- **OpenSSL**: Comprehensive cryptography library with support for P2P encryption.\n- **PyCryptodome**: Python library for implementing various cryptographic algorithms.\n- **Crypto**: Comprehensive cryptographic library for Node.js.\n- **libsodium**: Library for secure communications and P2P encryption.\n\nBy following this guide, you can set up secure, encrypted P2P communications similar to those used with financial transactions involving BINs. This setup will help protect sensitive information and ensure secure data sharing between peers.\n'

# %%
from smolagents import CodeAgent, InferenceClientModel, tool
from bs4 import BeautifulSoup as bsoup

import http.client as client
import json

@tool
def get_poc(dependency: str, manager: str) -> tuple[str,str,str,str]:
  """
  Search for vulnerabilities in dependency according to the package manager, elaborate a deatailed report that includes all the relevant information.
  Args:
    dependency: The dependency to search for.
    manager: The package manager for the dependency.
  Returns:
    This function returns a tuple with properties found in the vulnerable dependency.
  """
  osv_url = 'osv.dev'
  osv_api_url = 'api.osv.dev'
  nvd_url = 'nvd.nist.gov'

  prefix = 'https://' + osv_api_url

  data = send_request(osv_url, '/list?q=' + dependency + '&ecosystem=' + manager)
  docs = parse_content(data).find_all('div', class_='vuln-table-row mdc-data-table__row')

  aliases = []
  assets = []

  for index in docs:
    links = index.find_all('a')
    for link in links:
      assets.append(link.get('href'))

  inventory: tuple[str,str,str,str] = []

  for asset in assets:
    details = send_request(osv_url, asset)
    for link in parse_content(details).find_all('a'):
      if (link.get('href').startswith(prefix)):
        ref = link.get_text().strip()
        url = ref.removeprefix(prefix)

        report = send_request(osv_api_url, url)
        schema = json.loads(parse_content(report).get_text())

        context = []
        references = []

        cve = schema["aliases"][0]
        description = schema["details"]

        aliases.append(cve)

        record = send_request(nvd_url, '/vuln/detail/' + cve)
        for report in parse_content(record).find_all('table'):
          context.append(report.get_text().replace('\n','').replace('\t','').replace('\r',''))

        for ref in schema["references"]:
          references.append(ref['url'])

        inventory.append([cve, description, references, context])

  return inventory

def parse_content(data: str) -> bsoup:
  parser = bsoup(data, 'html.parser')
  return parser

def send_request(src: str, url: str) -> str:
  conn = client.HTTPSConnection(src)
  conn.request('GET', url)

  resp = conn.getresponse()
  data = resp.read().decode('utf-8')

  conn.close()
  return data

agent = CodeAgent(tools=[get_poc], model=InferenceClientModel())
agent.run("dependency: ollama, manager: Go")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ dependency: ollama, manager: Go                                                                                 │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   report = get_poc(dependency="ollama", manager="Go")
#   print(report)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# [['CVE-2025-1975', 'A vulnerability in the Ollama server version 0.5.11 allows a malicious user to cause a Denial
# of Service (DoS) attack by customizing the manifest content and spoofing a service. This is due to improper
# validation of array index access when downloading a model via the /api/pull endpoint, which can lead to a server
# crash.', ['https://nvd.nist.gov/vuln/detail/CVE-2025-1975', 'https://github.com/ollama/ollama',
# 'https://huntr.com/bounties/921ba5d4-f1d0-4c66-9764-4f72dffe7acd'], ['CVE-2025-1975                        Detail
# Awaiting AnalysisThis CVE record has been marked for NVD enrichment efforts.Description A vulnerability in the
# Ollama server version 0.5.11 allows a malicious user to cause a Denial of Service (DoS) attack by customizing the
# manifest content and spoofing a service. This is due to improper validation of array index access when downloading
# a model via the /api/pull endpoint, which can lead to a server crash.Metrics                                \u2002
# CVSS Version 4.0                                    CVSS Version 3.x                                    CVSS
# Version 2.0                                                                                NVD enrichment efforts
# reference publicly available information to associate                                            vector strings.
# CVSS information contributed by other sources is also                                            displayed.
# CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD assessment                                       not yet
# provided. CVSS 3.x Severity and Vector Strings:NIST:\xa0NVDBaseScore:\xa0 N/A NVD assessmentnot yet provided.
# CNA:\xa0 huntr.devBaseScore:\xa0 7.5 HIGHVector:\xa0 CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCVSS 2.0 Severity
# and Vector Strings:  NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to Advisories,
# Solutions, and Tools                                        By selecting these links, you will be leaving NIST
# webspace.                                        We have provided these links to other web sites because they
# may have information that would be of interest to you. No                                        inferences should
# be drawn on account of other sites being                                        referenced, or not, from this page.
# There may be other web                                        sites that are more appropriate for your purpose.
# NIST does                                        not necessarily endorse the views expressed, or concur with
# the facts presented on these sites. Further, NIST does not                                        endorse any
# commercial products that may be mentioned on                                        these sites. Please address
# comments about this page to [email\xa0protected].
# HyperlinkResourcehttps://huntr.com/bounties/921ba5d4-f1d0-4c66-9764-4f72dffe7acdWeakness EnumerationCWE-IDCWE
# NameSourceCWE-129Improper Validation of Array Indexhuntr.dev\u2003\u2003Change History 1 change records found show
# changesNew CVE Received from huntr.dev 5/16/2025 5:15:17 AMActionTypeOld ValueNew ValueAddedDescriptionA
# vulnerability in the Ollama server version 0.5.11 allows a malicious user to cause a Denial of Service (DoS) attack
# by customizing the manifest content and spoofing a service. This is due to improper validation of array index
# access when downloading a model via the /api/pull endpoint, which can lead to a server crash.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-129AddedReferencehttps://huntr.com/bounties/921ba5d4-f1d0-4c66-976
# 4-4f72dffe7acdQuick InfoCVE Dictionary Entry: CVE-2025-1975 NVD                                Published Date:
# 05/16/2025 NVD                                Last Modified: 05/16/2025                                 Source:
# huntr.dev', 'HyperlinkResourcehttps://huntr.com/bounties/921ba5d4-f1d0-4c66-9764-4f72dffe7acd', 'CWE-IDCWE
# NameSourceCWE-129Improper Validation of Array Indexhuntr.dev\u2003\u2003', 'ActionTypeOld ValueNew
# ValueAddedDescriptionA vulnerability in the Ollama server version 0.5.11 allows a malicious user to cause a Denial
# of Service (DoS) attack by customizing the manifest content and spoofing a service. This is due to improper
# validation of array index access when downloading a model via the /api/pull endpoint, which can lead to a server
# crash.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-129AddedReferencehttps://huntr.com/bounties/921ba5d4-f1d0-4c66-976
# 4-4f72dffe7acd']], ['CVE-2024-8063', 'Ollama Divide by Zero Vulnerability in github.com/ollama/ollama',
# ['https://github.com/advisories/GHSA-2xf2-gjm6-g2c6', 'https://github.com/ollama/ollama/issues/8020',
# 'https://huntr.com/bounties/fd8e1ed6-21d2-4c9e-8395-2098f11b7db9'], ['CVE-2024-8063                        Detail
# Description A divide by zero vulnerability exists in ollama/ollama version v0.3.3. The vulnerability occurs when
# importing GGUF models with a crafted type for `block_count` in the Modelfile. This can lead to a denial of service
# (DoS) condition when the server processes the model, causing it to crash.Metrics
# \u2002                                CVSS Version 4.0                                    CVSS Version 3.x
# CVSS Version 2.0                                                                                NVD enrichment
# efforts reference publicly available information to associate                                            vector
# strings. CVSS information contributed by other sources is also
# displayed.                                        CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD
# assessment                                       not yet provided. CVSS 3.x Severity and Vector
# Strings:NIST:\xa0NVDBaseScore:\xa0 7.5 HIGHVector:\xa0CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCNA:\xa0
# huntr.devBaseScore:\xa0 7.5 HIGHVector:\xa0 CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCVSS 2.0 Severity and
# Vector Strings:  NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to Advisories, Solutions,
# and Tools                                        By selecting these links, you will be leaving NIST webspace.
# We have provided these links to other web sites because they                                        may have
# information that would be of interest to you. No                                        inferences should be drawn
# on account of other sites being                                        referenced, or not, from this page. There
# may be other web                                        sites that are more appropriate for your purpose. NIST does
# not necessarily endorse the views expressed, or concur with                                        the facts
# presented on these sites. Further, NIST does not                                        endorse any commercial
# products that may be mentioned on                                        these sites. Please address comments about
# this page to [email\xa0protected].
# HyperlinkResourcehttps://huntr.com/bounties/fd8e1ed6-21d2-4c9e-8395-2098f11b7db9Exploit\xa0Third Party
# Advisory\xa0Weakness EnumerationCWE-IDCWE NameSourceCWE-369Divide By Zerohuntr.dev\u2003\u2003
# Known Affected Software Configurations  Switch                                        to CPE 2.2CPEs loading,
# please wait. Denotes Vulnerable SoftwareAre we missing a CPE here?  Please let us know.Change History 2 change
# records found show                                        changesInitial Analysis by NIST 5/13/2025 9:28:05
# AMActionTypeOld ValueNew ValueAddedCVSS V3.1AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCPE ConfigurationOR
# *cpe:2.3:a:ollama:ollama:0.3.3:*:*:*:*:*:*:*AddedReference Typehuntr.dev:
# https://huntr.com/bounties/fd8e1ed6-21d2-4c9e-8395-2098f11b7db9 Types: Exploit, Third Party AdvisoryNew CVE
# Received from huntr.dev 3/20/2025 6:15:40 AMActionTypeOld ValueNew ValueAddedDescriptionA divide by zero
# vulnerability exists in ollama/ollama version v0.3.3. The vulnerability occurs when importing GGUF models with a
# crafted type for `block_count` in the Modelfile. This can lead to a denial of service (DoS) condition when the
# server processes the model, causing it to crash.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-369AddedReferencehttps://huntr.com/bounties/fd8e1ed6-21d2-4c9e-839
# 5-2098f11b7db9Quick InfoCVE Dictionary Entry: CVE-2024-8063 NVD                                Published Date:
# 03/20/2025 NVD                                Last Modified: 05/13/2025                                 Source:
# huntr.dev', 'HyperlinkResourcehttps://huntr.com/bounties/fd8e1ed6-21d2-4c9e-8395-2098f11b7db9Exploit\xa0Third Party
# Advisory\xa0', 'CWE-IDCWE NameSourceCWE-369Divide By Zerohuntr.dev\u2003\u2003', 'ActionTypeOld ValueNew
# ValueAddedCVSS V3.1AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCPE ConfigurationOR
# *cpe:2.3:a:ollama:ollama:0.3.3:*:*:*:*:*:*:*AddedReference Typehuntr.dev:
# https://huntr.com/bounties/fd8e1ed6-21d2-4c9e-8395-2098f11b7db9 Types: Exploit, Third Party Advisory',
# 'ActionTypeOld ValueNew ValueAddedDescriptionA divide by zero vulnerability exists in ollama/ollama version v0.3.3.
# The vulnerability occurs when importing GGUF models with a crafted type for `block_count` in the Modelfile. This
# can lead to a denial of service (DoS) condition when the server processes the model, causing it to crash.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-369AddedReferencehttps://huntr.com/bounties/fd8e1ed6-21d2-4c9e-839
# 5-2098f11b7db9']], ['CVE-2025-0312', 'Ollama Denial of Service (DoS) via Null Pointer Dereference in
# github.com/ollama/ollama', ['https://github.com/advisories/GHSA-p2wh-w96x-w232',
# 'https://huntr.com/bounties/522c87b6-a7ac-41b2-84f3-62fd58921f21'], ['CVE-2025-0312                        Detail
# Description A vulnerability in ollama/ollama versions <=0.3.14 allows a malicious user to create a customized GGUF
# model file that, when uploaded and created on the Ollama server, can cause a crash due to an unchecked null pointer
# dereference. This can lead to a Denial of Service (DoS) attack via remote network.Metrics
# \u2002                                CVSS Version 4.0                                    CVSS Version 3.x
# CVSS Version 2.0                                                                                NVD enrichment
# efforts reference publicly available information to associate                                            vector
# strings. CVSS information contributed by other sources is also
# displayed.                                        CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD
# assessment                                       not yet provided. CVSS 3.x Severity and Vector
# Strings:NIST:\xa0NVDBaseScore:\xa0 7.5 HIGHVector:\xa0CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCNA:\xa0
# huntr.devBaseScore:\xa0 7.5 HIGHVector:\xa0 CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCVSS 2.0 Severity and
# Vector Strings:  NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to Advisories, Solutions,
# and Tools                                        By selecting these links, you will be leaving NIST webspace.
# We have provided these links to other web sites because they                                        may have
# information that would be of interest to you. No                                        inferences should be drawn
# on account of other sites being                                        referenced, or not, from this page. There
# may be other web                                        sites that are more appropriate for your purpose. NIST does
# not necessarily endorse the views expressed, or concur with                                        the facts
# presented on these sites. Further, NIST does not                                        endorse any commercial
# products that may be mentioned on                                        these sites. Please address comments about
# this page to [email\xa0protected].
# HyperlinkResourcehttps://huntr.com/bounties/522c87b6-a7ac-41b2-84f3-62fd58921f21Exploit\xa0Third Party
# Advisory\xa0Weakness EnumerationCWE-IDCWE NameSourceCWE-476NULL Pointer
# DereferenceNIST\u2003\u2003huntr.dev\u2003\u2003                                        Known Affected Software
# Configurations  Switch                                        to CPE 2.2CPEs loading, please wait. Denotes
# Vulnerable SoftwareAre we missing a CPE here?  Please let us know.Change History 2 change records found show
# changesInitial Analysis by NIST 3/28/2025 10:11:12 AMActionTypeOld ValueNew ValueAddedCVSS
# V3.1AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-476AddedCPE ConfigurationOR
# *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions up to (including) 0.3.14AddedReference Typehuntr.dev:
# https://huntr.com/bounties/522c87b6-a7ac-41b2-84f3-62fd58921f21 Types: Exploit, Third Party AdvisoryNew CVE
# Received from huntr.dev 3/20/2025 6:15:52 AMActionTypeOld ValueNew ValueAddedDescriptionA vulnerability in
# ollama/ollama versions <=0.3.14 allows a malicious user to create a customized GGUF model file that, when uploaded
# and created on the Ollama server, can cause a crash due to an unchecked null pointer dereference. This can lead to
# a Denial of Service (DoS) attack via remote network.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-476AddedReferencehttps://huntr.com/bounties/522c87b6-a7ac-41b2-84f
# 3-62fd58921f21Quick InfoCVE Dictionary Entry: CVE-2025-0312 NVD                                Published Date:
# 03/20/2025 NVD                                Last Modified: 03/28/2025                                 Source:
# huntr.dev', 'HyperlinkResourcehttps://huntr.com/bounties/522c87b6-a7ac-41b2-84f3-62fd58921f21Exploit\xa0Third Party
# Advisory\xa0', 'CWE-IDCWE NameSourceCWE-476NULL Pointer DereferenceNIST\u2003\u2003huntr.dev\u2003\u2003',
# 'ActionTypeOld ValueNew ValueAddedCVSS V3.1AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-476AddedCPE
# ConfigurationOR          *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions up to (including) 0.3.14AddedReference
# Typehuntr.dev: https://huntr.com/bounties/522c87b6-a7ac-41b2-84f3-62fd58921f21 Types: Exploit, Third Party
# Advisory', 'ActionTypeOld ValueNew ValueAddedDescriptionA vulnerability in ollama/ollama versions <=0.3.14 allows a
# malicious user to create a customized GGUF model file that, when uploaded and created on the Ollama server, can
# cause a crash due to an unchecked null pointer dereference. This can lead to a Denial of Service (DoS) attack via
# remote network.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-476AddedReferencehttps://huntr.com/bounties/522c87b6-a7ac-41b2-84f
# 3-62fd58921f21']], ['CVE-2024-12886', 'Ollama Vulnerable to Denial of Service (DoS) via Crafted GZIP in
# github.com/ollama/ollama', ['https://github.com/advisories/GHSA-v464-r2r9-www7',
# 'https://huntr.com/bounties/f115fe52-58af-4844-ad29-b1c25f7245df'], ['CVE-2024-12886                        Detail
# Awaiting AnalysisThis CVE record has been marked for NVD enrichment efforts.Description An Out-Of-Memory (OOM)
# vulnerability exists in the `ollama` server version 0.3.14. This vulnerability can be triggered when a malicious
# API server responds with a gzip bomb HTTP response, leading to the `ollama` server crashing. The vulnerability is
# present in the `makeRequestWithRetry` and `getAuthorizationToken` functions, which use `io.ReadAll` to read the
# response body. This can result in excessive memory usage and a Denial of Service (DoS) condition.Metrics
# \u2002                                CVSS Version 4.0                                    CVSS Version 3.x
# CVSS Version 2.0                                                                                NVD enrichment
# efforts reference publicly available information to associate                                            vector
# strings. CVSS information contributed by other sources is also
# displayed.                                        CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD
# assessment                                       not yet provided. CVSS 3.x Severity and Vector
# Strings:NIST:\xa0NVDBaseScore:\xa0 N/A NVD assessmentnot yet provided. CNA:\xa0 huntr.devBaseScore:\xa0 7.5
# HIGHVector:\xa0 CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCVSS 2.0 Severity and Vector Strings:
# NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to Advisories, Solutions, and Tools
# By selecting these links, you will be leaving NIST webspace.                                        We have
# provided these links to other web sites because they                                        may have information
# that would be of interest to you. No                                        inferences should be drawn on account
# of other sites being                                        referenced, or not, from this page. There may be other
# web                                        sites that are more appropriate for your purpose. NIST does
# not necessarily endorse the views expressed, or concur with                                        the facts
# presented on these sites. Further, NIST does not                                        endorse any commercial
# products that may be mentioned on                                        these sites. Please address comments about
# this page to [email\xa0protected].
# HyperlinkResourcehttps://huntr.com/bounties/f115fe52-58af-4844-ad29-b1c25f7245dfWeakness EnumerationCWE-IDCWE
# NameSourceCWE-400Uncontrolled Resource Consumptionhuntr.dev\u2003\u2003Change History 1 change records found show
# changesNew CVE Received from huntr.dev 3/20/2025 6:15:31 AMActionTypeOld ValueNew ValueAddedDescriptionAn
# Out-Of-Memory (OOM) vulnerability exists in the `ollama` server version 0.3.14. This vulnerability can be triggered
# when a malicious API server responds with a gzip bomb HTTP response, leading to the `ollama` server crashing. The
# vulnerability is present in the `makeRequestWithRetry` and `getAuthorizationToken` functions, which use
# `io.ReadAll` to read the response body. This can result in excessive memory usage and a Denial of Service (DoS)
# condition.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-400AddedReferencehttps://huntr.com/bounties/f115fe52-58af-4844-ad2
# 9-b1c25f7245dfQuick InfoCVE Dictionary Entry: CVE-2024-12886 NVD                                Published Date:
# 03/20/2025 NVD                                Last Modified: 03/20/2025                                 Source:
# huntr.dev', 'HyperlinkResourcehttps://huntr.com/bounties/f115fe52-58af-4844-ad29-b1c25f7245df', 'CWE-IDCWE
# NameSourceCWE-400Uncontrolled Resource Consumptionhuntr.dev\u2003\u2003', 'ActionTypeOld ValueNew
# ValueAddedDescriptionAn Out-Of-Memory (OOM) vulnerability exists in the `ollama` server version 0.3.14. This
# vulnerability can be triggered when a malicious API server responds with a gzip bomb HTTP response, leading to the
# `ollama` server crashing. The vulnerability is present in the `makeRequestWithRetry` and `getAuthorizationToken`
# functions, which use `io.ReadAll` to read the response body. This can result in excessive memory usage and a Denial
# of Service (DoS) condition.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-400AddedReferencehttps://huntr.com/bounties/f115fe52-58af-4844-ad2
# 9-b1c25f7245df']], ['CVE-2025-0315', 'Ollama Allocation of Resources Without Limits or Throttling vulnerability in
# github.com/ollama/ollama', ['https://github.com/advisories/GHSA-fccc-8m69-8r78',
# 'https://huntr.com/bounties/da414d29-b55a-496f-b135-17e0fcec67bc'], ['CVE-2025-0315                        Detail
# Description A vulnerability in ollama/ollama <=0.3.14 allows a malicious user to create a customized GGUF model
# file, upload it to the Ollama server, and create it. This can cause the server to allocate unlimited memory,
# leading to a Denial of Service (DoS) attack.Metrics                                \u2002
# CVSS Version 4.0                                    CVSS Version 3.x                                    CVSS
# Version 2.0                                                                                NVD enrichment efforts
# reference publicly available information to associate                                            vector strings.
# CVSS information contributed by other sources is also                                            displayed.
# CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD assessment                                       not yet
# provided. CVSS 3.x Severity and Vector Strings:NIST:\xa0NVDBaseScore:\xa0 7.5
# HIGHVector:\xa0CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCNA:\xa0 huntr.devBaseScore:\xa0 7.5 HIGHVector:\xa0
# CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCVSS 2.0 Severity and Vector Strings:  NIST:\xa0NVDBaseScore:\xa0N/ANVD
# assessmentnot yet provided. References to Advisories, Solutions, and Tools
# By selecting these links, you will be leaving NIST webspace.                                        We have
# provided these links to other web sites because they                                        may have information
# that would be of interest to you. No                                        inferences should be drawn on account
# of other sites being                                        referenced, or not, from this page. There may be other
# web                                        sites that are more appropriate for your purpose. NIST does
# not necessarily endorse the views expressed, or concur with                                        the facts
# presented on these sites. Further, NIST does not                                        endorse any commercial
# products that may be mentioned on                                        these sites. Please address comments about
# this page to [email\xa0protected].
# HyperlinkResourcehttps://huntr.com/bounties/da414d29-b55a-496f-b135-17e0fcec67bcExploit\xa0Third Party
# Advisory\xa0Weakness EnumerationCWE-IDCWE NameSourceCWE-770Allocation of Resources Without Limits or
# ThrottlingNIST\u2003\u2003huntr.dev\u2003\u2003                                        Known Affected Software
# Configurations  Switch                                        to CPE 2.2CPEs loading, please wait. Denotes
# Vulnerable SoftwareAre we missing a CPE here?  Please let us know.Change History 2 change records found show
# changesInitial Analysis by NIST 4/02/2025 12:02:38 PMActionTypeOld ValueNew ValueAddedCVSS
# V3.1AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-770AddedCPE ConfigurationOR
# *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions up to (including) 0.3.14AddedReference Typehuntr.dev:
# https://huntr.com/bounties/da414d29-b55a-496f-b135-17e0fcec67bc Types: Exploit, Third Party AdvisoryNew CVE
# Received from huntr.dev 3/20/2025 6:15:52 AMActionTypeOld ValueNew ValueAddedDescriptionA vulnerability in
# ollama/ollama <=0.3.14 allows a malicious user to create a customized GGUF model file, upload it to the Ollama
# server, and create it. This can cause the server to allocate unlimited memory, leading to a Denial of Service (DoS)
# attack.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-770AddedReferencehttps://huntr.com/bounties/da414d29-b55a-496f-b13
# 5-17e0fcec67bcQuick InfoCVE Dictionary Entry: CVE-2025-0315 NVD                                Published Date:
# 03/20/2025 NVD                                Last Modified: 04/02/2025                                 Source:
# huntr.dev', 'HyperlinkResourcehttps://huntr.com/bounties/da414d29-b55a-496f-b135-17e0fcec67bcExploit\xa0Third Party
# Advisory\xa0', 'CWE-IDCWE NameSourceCWE-770Allocation of Resources Without Limits or
# ThrottlingNIST\u2003\u2003huntr.dev\u2003\u2003', 'ActionTypeOld ValueNew ValueAddedCVSS V3.1AV:N/AC:L/PR:N/UI
# ..._This content has been truncated to stay below 50000 characters_...
# N/A:HCNA:\xa0 huntr.devBaseScore:\xa0 7.5 HIGHVector:\xa0 CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HCVSS 2.0
# Severity and Vector Strings:  NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to
# Advisories, Solutions, and Tools                                        By selecting these links, you will be
# leaving NIST webspace.                                        We have provided these links to other web sites
# because they                                        may have information that would be of interest to you. No
# inferences should be drawn on account of other sites being                                        referenced, or
# not, from this page. There may be other web                                        sites that are more appropriate
# for your purpose. NIST does                                        not necessarily endorse the views expressed, or
# concur with                                        the facts presented on these sites. Further, NIST does not
# endorse any commercial products that may be mentioned on                                        these sites. Please
# address comments about this page to [email\xa0protected].
# HyperlinkResourcehttps://huntr.com/bounties/7b111d55-8215-4727-8807-c5ed4cf1bfbeExploit\xa0Third Party
# Advisory\xa0Weakness EnumerationCWE-IDCWE NameSourceCWE-125Out-of-bounds Readhuntr.dev\u2003\u2003
# Known Affected Software Configurations  Switch                                        to CPE 2.2CPEs loading,
# please wait. Denotes Vulnerable SoftwareAre we missing a CPE here?  Please let us know.Change History 2 change
# records found show                                        changesInitial Analysis by NIST 5/13/2025 9:28:08
# AMActionTypeOld ValueNew ValueAddedCVSS V3.1AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCPE ConfigurationOR
# *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions up to (including) 0.3.14AddedReference Typehuntr.dev:
# https://huntr.com/bounties/7b111d55-8215-4727-8807-c5ed4cf1bfbe Types: Exploit, Third Party AdvisoryNew CVE
# Received from huntr.dev 3/20/2025 6:15:26 AMActionTypeOld ValueNew ValueAddedDescriptionA vulnerability in Ollama
# versions <=0.3.14 allows a malicious user to create a customized gguf model file that can be uploaded to the public
# Ollama server. When the server processes this malicious model, it crashes, leading to a Denial of Service (DoS)
# attack. The root cause of the issue is an out-of-bounds read in the gguf.go file.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-125AddedReferencehttps://huntr.com/bounties/7b111d55-8215-4727-880
# 7-c5ed4cf1bfbeQuick InfoCVE Dictionary Entry: CVE-2024-12055 NVD                                Published Date:
# 03/20/2025 NVD                                Last Modified: 05/13/2025                                 Source:
# huntr.dev', 'HyperlinkResourcehttps://huntr.com/bounties/7b111d55-8215-4727-8807-c5ed4cf1bfbeExploit\xa0Third Party
# Advisory\xa0', 'CWE-IDCWE NameSourceCWE-125Out-of-bounds Readhuntr.dev\u2003\u2003', 'ActionTypeOld ValueNew
# ValueAddedCVSS V3.1AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCPE ConfigurationOR
# *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions up to (including) 0.3.14AddedReference Typehuntr.dev:
# https://huntr.com/bounties/7b111d55-8215-4727-8807-c5ed4cf1bfbe Types: Exploit, Third Party Advisory',
# 'ActionTypeOld ValueNew ValueAddedDescriptionA vulnerability in Ollama versions <=0.3.14 allows a malicious user to
# create a customized gguf model file that can be uploaded to the public Ollama server. When the server processes
# this malicious model, it crashes, leading to a Denial of Service (DoS) attack. The root cause of the issue is an
# out-of-bounds read in the gguf.go file.AddedCVSS
# V3AV:N/AC:L/PR:N/UI:N/S:U/C:N/I:N/A:HAddedCWECWE-125AddedReferencehttps://huntr.com/bounties/7b111d55-8215-4727-880
# 7-c5ed4cf1bfbe']], ['CVE-2024-39720', 'Ollama Out-of-bounds Read in github.com/ollama/ollama',
# ['https://github.com/advisories/GHSA-95j2-w8x7-hm88',
# 'https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806
# ac5517b4563131L417', 'https://oligo.security/blog/more-models-more-probllms'], ['CVE-2024-39720
# Detail                    Description An issue was discovered in Ollama before 0.1.46. An attacker can use two HTTP
# requests to upload a malformed GGUF file containing just 4 bytes starting with the GGUF custom magic header. By
# leveraging a custom Modelfile that includes a FROM statement pointing to the attacker-controlled blob file, the
# attacker can crash the application through the CreateModel route, leading to a segmentation fault (signal SIGSEGV:
# segmentation violation).Metrics                                \u2002                                CVSS Version
# 4.0                                    CVSS Version 3.x                                    CVSS Version 2.0
# NVD enrichment efforts reference publicly available information to associate
# vector strings. CVSS information contributed by other sources is also
# displayed.                                        CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD
# assessment                                       not yet provided. CVSS 3.x Severity and Vector
# Strings:NIST:\xa0NVDBaseScore:\xa0 N/A NVD assessmentnot yet provided. ADP:\xa0 CISA-ADPBaseScore:\xa0 8.2
# HIGHVector:\xa0 CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:HCVSS 2.0 Severity and Vector Strings:
# NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to Advisories, Solutions, and Tools
# By selecting these links, you will be leaving NIST webspace.                                        We have
# provided these links to other web sites because they                                        may have information
# that would be of interest to you. No                                        inferences should be drawn on account
# of other sites being                                        referenced, or not, from this page. There may be other
# web                                        sites that are more appropriate for your purpose. NIST does
# not necessarily endorse the views expressed, or concur with                                        the facts
# presented on these sites. Further, NIST does not                                        endorse any commercial
# products that may be mentioned on                                        these sites. Please address comments about
# this page to [email\xa0protected].
# HyperlinkResourcehttps://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf4002
# 3e7067baccd4f806ac5517b4563131L417Product\xa0https://oligo.security/blog/more-models-more-probllmsExploit\xa0Third
# Party Advisory\xa0Weakness EnumerationCWE-IDCWE NameSourceCWE-125Out-of-bounds ReadCISA-ADP\u2003\u2003
# Known Affected Software Configurations  Switch                                        to CPE 2.2CPEs loading,
# please wait. Denotes Vulnerable SoftwareAre we missing a CPE here?  Please let us know.Change History 4 change
# records found show                                        changesInitial Analysis by NIST 5/13/2025 9:28:14
# AMActionTypeOld ValueNew ValueAddedCPE ConfigurationOR          *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions
# up to (excluding) 0.1.46AddedReference TypeMITRE:
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 Types: ProductAddedReference TypeMITRE: https://oligo.security/blog/more-models-more-probllms
# Types: Exploit, Third Party AdvisoryCVE Modified by CISA-ADP 11/01/2024 12:35:23 PMActionTypeOld ValueNew
# ValueAddedCVSS V3.1CISA-ADP AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:HAddedCWECISA-ADP CWE-125CVE Modified by MITRE
# 11/01/2024 10:15:06 AMActionTypeOld ValueNew ValueAddedReferenceMITRE
# https://oligo.security/blog/more-models-more-probllms [No types assigned]RemovedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllmsNew CVE Received from MITRE 10/31/2024 4:15:04
# PMActionTypeOld ValueNew ValueAddedDescriptionAn issue was discovered in Ollama before 0.1.46. An attacker can use
# two HTTP requests to upload a malformed GGUF file containing just 4 bytes starting with the GGUF custom magic
# header. By leveraging a custom Modelfile that includes a FROM statement pointing to the attacker-controlled blob
# file, the attacker can crash the application through the CreateModel route, leading to a segmentation fault (signal
# SIGSEGV: segmentation violation).AddedReferenceMITRE
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 [No types assigned]AddedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllms [No types assigned]Quick InfoCVE Dictionary Entry:
# CVE-2024-39720 NVD                                Published Date: 10/31/2024 NVD
# Last Modified: 05/13/2025                                 Source: MITRE',
# 'HyperlinkResourcehttps://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf400
# 23e7067baccd4f806ac5517b4563131L417Product\xa0https://oligo.security/blog/more-models-more-probllmsExploit\xa0Third
#  Party Advisory\xa0', 'CWE-IDCWE NameSourceCWE-125Out-of-bounds ReadCISA-ADP\u2003\u2003', 'ActionTypeOld ValueNew
# ValueAddedCPE ConfigurationOR          *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions up to (excluding)
# 0.1.46AddedReference TypeMITRE:
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 Types: ProductAddedReference TypeMITRE: https://oligo.security/blog/more-models-more-probllms
# Types: Exploit, Third Party Advisory', 'ActionTypeOld ValueNew ValueAddedCVSS V3.1CISA-ADP
# AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:HAddedCWECISA-ADP CWE-125', 'ActionTypeOld ValueNew ValueAddedReferenceMITRE
# https://oligo.security/blog/more-models-more-probllms [No types assigned]RemovedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllms', 'ActionTypeOld ValueNew ValueAddedDescriptionAn
# issue was discovered in Ollama before 0.1.46. An attacker can use two HTTP requests to upload a malformed GGUF file
# containing just 4 bytes starting with the GGUF custom magic header. By leveraging a custom Modelfile that includes
# a FROM statement pointing to the attacker-controlled blob file, the attacker can crash the application through the
# CreateModel route, leading to a segmentation fault (signal SIGSEGV: segmentation violation).AddedReferenceMITRE
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 [No types assigned]AddedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllms [No types assigned]']], ['CVE-2024-39720', 'An
# issue was discovered in Ollama before 0.1.46. An attacker can use two HTTP requests to upload a malformed GGUF file
# containing just 4 bytes starting with the GGUF custom magic header. By leveraging a custom Modelfile that includes
# a FROM statement pointing to the attacker-controlled blob file, the attacker can crash the application through the
# CreateModel route, leading to a segmentation fault (signal SIGSEGV: segmentation violation).',
# ['https://nvd.nist.gov/vuln/detail/CVE-2024-39720', 'https://github.com/ollama/ollama',
# 'https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806
# ac5517b4563131L417', 'https://oligo.security/blog/more-models-more-probllms',
# 'https://oligosecurity.webflow.io/blog/more-models-more-probllms', 'https://pkg.go.dev/vuln/GO-2024-3245'],
# ['CVE-2024-39720                        Detail                    Description An issue was discovered in Ollama
# before 0.1.46. An attacker can use two HTTP requests to upload a malformed GGUF file containing just 4 bytes
# starting with the GGUF custom magic header. By leveraging a custom Modelfile that includes a FROM statement
# pointing to the attacker-controlled blob file, the attacker can crash the application through the CreateModel
# route, leading to a segmentation fault (signal SIGSEGV: segmentation violation).Metrics
# \u2002                                CVSS Version 4.0                                    CVSS Version 3.x
# CVSS Version 2.0                                                                                NVD enrichment
# efforts reference publicly available information to associate                                            vector
# strings. CVSS information contributed by other sources is also
# displayed.                                        CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD
# assessment                                       not yet provided. CVSS 3.x Severity and Vector
# Strings:NIST:\xa0NVDBaseScore:\xa0 N/A NVD assessmentnot yet provided. ADP:\xa0 CISA-ADPBaseScore:\xa0 8.2
# HIGHVector:\xa0 CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:HCVSS 2.0 Severity and Vector Strings:
# NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to Advisories, Solutions, and Tools
# By selecting these links, you will be leaving NIST webspace.                                        We have
# provided these links to other web sites because they                                        may have information
# that would be of interest to you. No                                        inferences should be drawn on account
# of other sites being                                        referenced, or not, from this page. There may be other
# web                                        sites that are more appropriate for your purpose. NIST does
# not necessarily endorse the views expressed, or concur with                                        the facts
# presented on these sites. Further, NIST does not                                        endorse any commercial
# products that may be mentioned on                                        these sites. Please address comments about
# this page to [email\xa0protected].
# HyperlinkResourcehttps://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf4002
# 3e7067baccd4f806ac5517b4563131L417Product\xa0https://oligo.security/blog/more-models-more-probllmsExploit\xa0Third
# Party Advisory\xa0Weakness EnumerationCWE-IDCWE NameSourceCWE-125Out-of-bounds ReadCISA-ADP\u2003\u2003
# Known Affected Software Configurations  Switch                                        to CPE 2.2CPEs loading,
# please wait. Denotes Vulnerable SoftwareAre we missing a CPE here?  Please let us know.Change History 4 change
# records found show                                        changesInitial Analysis by NIST 5/13/2025 9:28:14
# AMActionTypeOld ValueNew ValueAddedCPE ConfigurationOR          *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions
# up to (excluding) 0.1.46AddedReference TypeMITRE:
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 Types: ProductAddedReference TypeMITRE: https://oligo.security/blog/more-models-more-probllms
# Types: Exploit, Third Party AdvisoryCVE Modified by CISA-ADP 11/01/2024 12:35:23 PMActionTypeOld ValueNew
# ValueAddedCVSS V3.1CISA-ADP AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:HAddedCWECISA-ADP CWE-125CVE Modified by MITRE
# 11/01/2024 10:15:06 AMActionTypeOld ValueNew ValueAddedReferenceMITRE
# https://oligo.security/blog/more-models-more-probllms [No types assigned]RemovedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllmsNew CVE Received from MITRE 10/31/2024 4:15:04
# PMActionTypeOld ValueNew ValueAddedDescriptionAn issue was discovered in Ollama before 0.1.46. An attacker can use
# two HTTP requests to upload a malformed GGUF file containing just 4 bytes starting with the GGUF custom magic
# header. By leveraging a custom Modelfile that includes a FROM statement pointing to the attacker-controlled blob
# file, the attacker can crash the application through the CreateModel route, leading to a segmentation fault (signal
# SIGSEGV: segmentation violation).AddedReferenceMITRE
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 [No types assigned]AddedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllms [No types assigned]Quick InfoCVE Dictionary Entry:
# CVE-2024-39720 NVD                                Published Date: 10/31/2024 NVD
# Last Modified: 05/13/2025                                 Source: MITRE',
# 'HyperlinkResourcehttps://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf400
# 23e7067baccd4f806ac5517b4563131L417Product\xa0https://oligo.security/blog/more-models-more-probllmsExploit\xa0Third
#  Party Advisory\xa0', 'CWE-IDCWE NameSourceCWE-125Out-of-bounds ReadCISA-ADP\u2003\u2003', 'ActionTypeOld ValueNew
# ValueAddedCPE ConfigurationOR          *cpe:2.3:a:ollama:ollama:*:*:*:*:*:*:*:* versions up to (excluding)
# 0.1.46AddedReference TypeMITRE:
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 Types: ProductAddedReference TypeMITRE: https://oligo.security/blog/more-models-more-probllms
# Types: Exploit, Third Party Advisory', 'ActionTypeOld ValueNew ValueAddedCVSS V3.1CISA-ADP
# AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:HAddedCWECISA-ADP CWE-125', 'ActionTypeOld ValueNew ValueAddedReferenceMITRE
# https://oligo.security/blog/more-models-more-probllms [No types assigned]RemovedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllms', 'ActionTypeOld ValueNew ValueAddedDescriptionAn
# issue was discovered in Ollama before 0.1.46. An attacker can use two HTTP requests to upload a malformed GGUF file
# containing just 4 bytes starting with the GGUF custom magic header. By leveraging a custom Modelfile that includes
# a FROM statement pointing to the attacker-controlled blob file, the attacker can crash the application through the
# CreateModel route, leading to a segmentation fault (signal SIGSEGV: segmentation violation).AddedReferenceMITRE
# https://github.com/ollama/ollama/compare/v0.1.45...v0.1.46#diff-782c2737eecfa83b7cb46a77c8bdaf40023e7067baccd4f806a
# c5517b4563131L417 [No types assigned]AddedReferenceMITRE
# https://oligosecurity.webflow.io/blog/more-models-more-probllms [No types assigned]']], ['CVE-2024-45436', 'Ollama
# can extract members of a ZIP archive outside of the parent directory in github.com/ollama/ollama',
# ['https://github.com/advisories/GHSA-846m-99qv-67mg',
# 'https://github.com/ollama/ollama/commit/123a722a6f541e300bc8e34297ac378ebe23f527',
# 'https://github.com/ollama/ollama/pull/5314', 'https://github.com/ollama/ollama/compare/v0.1.46...v0.1.47'],
# ["CVE-2024-45436                        Detail                    Description extractFromZipFile in model.go in
# Ollama before 0.1.47 can extract members of a ZIP archive outside of the parent directory.Metrics
# \u2002                                CVSS Version 4.0                                    CVSS Version 3.x
# CVSS Version 2.0                                                                                NVD enrichment
# efforts reference publicly available information to associate                                            vector
# strings. CVSS information contributed by other sources is also
# displayed.                                        CVSS 4.0 Severity and Vector Strings:NIST:\xa0NVD  N/A NVD
# assessment                                       not yet provided. CVSS 3.x Severity and Vector
# Strings:NIST:\xa0NVDBaseScore:\xa0 7.5 HIGHVector:\xa0CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:N/A:NADP:\xa0
# CISA-ADPBaseScore:\xa0 9.1 CRITICALVector:\xa0 CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:NCVSS 2.0 Severity and
# Vector Strings:  NIST:\xa0NVDBaseScore:\xa0N/ANVD assessmentnot yet provided. References to Advisories, Solutions,
# and Tools                                        By selecting these links, you will be leaving NIST webspace.
# We have provided these links to other web sites because they                                        may have
# information that would be of interest to you. No                                        inferences should be drawn
# on account of other sites being                                        referenced, or not, from this page. There
# may be other web                                        sites that are more appropriate for your purpose. NIST does
# not necessarily endorse the views expressed, or concur with                                        the facts
# presented on these sites. Further, NIST does not                                        endorse any commercial
# products that may be mentioned on                                        these sites. Please address comments about
# this page to [email\xa0protected].
# HyperlinkResourcehttps://github.com/ollama/ollama/compare/v0.1.46...v0.1.47Patch\xa0https://github.com/ollama/ollam
# a/pull/5314Patch\xa0Weakness EnumerationCWE-IDCWE NameSourceCWE-22Improper Limitation of a Pathname to a Restricted
# Directory ('Path Traversal')NIST\u2003\u2003CISA-ADP\u2003\u2003                                        Known
# Affected Software Configurations  Switch                                        to CPE 2.2CPEs loading, please
# wait. Denotes Vulnerable SoftwareAre we missing a CPE here?  Please let us know.Change History 3 change records
# found show                                        changesInitial Analysis by NIST 8/30/2024 12:08:54
# PMActionTypeOld ValueNew ValueAddedCVSS V3.1NIST AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:N/A:NAddedCWENIST CWE-22AddedCPE
# ...
# [Step 1: Duration 23.59 seconds| Input tokens: 2,061 | Output tokens: 70]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#
#   # Extracting CVEs and their descriptions
#   cves = re.findall(r"CVE-\d{4}-\d{4,7}", report)
#   descriptions = re.findall(r"Description (.*?)Metrics", report, re.DOTALL)
#
#   # Printing the CVEs and their descriptions
#   for cve, description in zip(cves, descriptions):
#       print(f"{cve}: {description.strip()}")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'cves = re.findall(r"CVE-\d{4}-\d{4,7}", report)' due to: TypeError: expected string
# or bytes-like object, got 'list'
# [Step 2: Duration 20.46 seconds| Input tokens: 18,165 | Output tokens: 220]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#
#   # Assuming report is a list of lists with the structure: [[CVE_ID, Description, References, Detail]]
#   final_report = []
#
#   for entry in report:
#       if len(entry) > 1:
#           cve = entry[0]
#           description = entry[1].split("Metrics", 1)[0].strip()  # Split at "Metrics" to get the description
#           final_report.append(f"{cve}: {description}")
#
#   # Printing the CVEs and their descriptions
#   for item in final_report:
#       print(item)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# CVE-2025-1975: A vulnerability in the Ollama server version 0.5.11 allows a malicious user to cause a Denial of
# Service (DoS) attack by customizing the manifest content and spoofing a service. This is due to improper validation
# of array index access when downloading a model via the /api/pull endpoint, which can lead to a server crash.
# CVE-2024-8063: Ollama Divide by Zero Vulnerability in github.com/ollama/ollama
# CVE-2025-0312: Ollama Denial of Service (DoS) via Null Pointer Dereference in github.com/ollama/ollama
# CVE-2024-12886: Ollama Vulnerable to Denial of Service (DoS) via Crafted GZIP in github.com/ollama/ollama
# CVE-2025-0315: Ollama Allocation of Resources Without Limits or Throttling vulnerability in
# github.com/ollama/ollama
# CVE-2024-12055: Ollama Allows Out-of-Bounds Read in github.com/ollama/ollama
# CVE-2025-0317: Ollama Divide By Zero vulnerability in github.com/ollama/ollama
# CVE-2025-0317: A vulnerability in ollama/ollama versions <=0.3.14 allows a malicious user to upload and create a
# customized GGUF model file on the Ollama server. This can lead to a division by zero error in the ggufPadding
# function, causing the server to crash and resulting in a Denial of Service (DoS) attack.
# CVE-2025-0315: A vulnerability in ollama/ollama <=0.3.14 allows a malicious user to create a customized GGUF model
# file, upload it to the Ollama server, and create it. This can cause the server to allocate unlimited memory,
# leading to a Denial of Service (DoS) attack.
# CVE-2025-0312: A vulnerability in ollama/ollama versions <=0.3.14 allows a malicious user to create a customized
# GGUF model file that, when uploaded and created on the Ollama server, can cause a crash due to an unchecked null
# pointer dereference. This can lead to a Denial of Service (DoS) attack via remote network.
# CVE-2024-8063: A divide by zero vulnerability exists in ollama/ollama version v0.3.3. The vulnerability occurs when
# importing GGUF models with a crafted type for `block_count` in the Modelfile. This can lead to a denial of service
# (DoS) condition when the server processes the model, causing it to crash.
# CVE-2024-12886: An Out-Of-Memory (OOM) vulnerability exists in the `ollama` server version 0.3.14. This
# vulnerability can be triggered when a malicious API server responds with a gzip bomb HTTP response, leading to the
# `ollama` server crashing. The vulnerability is present in the `makeRequestWithRetry` and `getAuthorizationToken`
# functions, which use `io.ReadAll` to read the response body. This can result in excessive memory usage and a Denial
# of Service (DoS) condition.
# CVE-2024-12055: A vulnerability in Ollama versions <=0.3.14 allows a malicious user to create a customized gguf
# model file that can be uploaded to the public Ollama server. When the server processes this malicious model, it
# crashes, leading to a Denial of Service (DoS) attack. The root cause of the issue is an out-of-bounds read in the
# gguf.go file.
# CVE-2024-39720: Ollama Out-of-bounds Read in github.com/ollama/ollama
# CVE-2024-39720: An issue was discovered in Ollama before 0.1.46. An attacker can use two HTTP requests to upload a
# malformed GGUF file containing just 4 bytes starting with the GGUF custom magic header. By leveraging a custom
# Modelfile that includes a FROM statement pointing to the attacker-controlled blob file, the attacker can crash the
# application through the CreateModel route, leading to a segmentation fault (signal SIGSEGV: segmentation
# violation).
# CVE-2024-45436: Ollama can extract members of a ZIP archive outside of the parent directory in
# github.com/ollama/ollama
#
# Out: None
# [Step 3: Duration 12.87 seconds| Input tokens: 34,636 | Output tokens: 388]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Compiling a concise summary of the vulnerabilities
#   summary = "Vulnerabilities in the ollama dependency (Go package manager):\n"
#   for item in final_report:
#       summary += f"- {item}\n"
#
#   # Providing the final answer
#   final_answer(summary)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Vulnerabilities in the ollama dependency (Go package manager):
# - CVE-2025-1975: A vulnerability in the Ollama server version 0.5.11 allows a malicious user to cause a Denial of
# Service (DoS) attack by customizing the manifest content and spoofing a service. This is due to improper validation
# of array index access when downloading a model via the /api/pull endpoint, which can lead to a server crash.
# - CVE-2024-8063: Ollama Divide by Zero Vulnerability in github.com/ollama/ollama
# - CVE-2025-0312: Ollama Denial of Service (DoS) via Null Pointer Dereference in github.com/ollama/ollama
# - CVE-2024-12886: Ollama Vulnerable to Denial of Service (DoS) via Crafted GZIP in github.com/ollama/ollama
# - CVE-2025-0315: Ollama Allocation of Resources Without Limits or Throttling vulnerability in
# github.com/ollama/ollama
# - CVE-2024-12055: Ollama Allows Out-of-Bounds Read in github.com/ollama/ollama
# - CVE-2025-0317: Ollama Divide By Zero vulnerability in github.com/ollama/ollama
# - CVE-2025-0317: A vulnerability in ollama/ollama versions <=0.3.14 allows a malicious user to upload and create a
# customized GGUF model file on the Ollama server. This can lead to a division by zero error in the ggufPadding
# function, causing the server to crash and resulting in a Denial of Service (DoS) attack.
# - CVE-2025-0315: A vulnerability in ollama/ollama <=0.3.14 allows a malicious user to create a customized GGUF
# model file, upload it to the Ollama server, and create it. This can cause the server to allocate unlimited memory,
# leading to a Denial of Service (DoS) attack.
# - CVE-2025-0312: A vulnerability in ollama/ollama versions <=0.3.14 allows a malicious user to create a customized
# GGUF model file that, when uploaded and created on the Ollama server, can cause a crash due to an unchecked null
# pointer dereference. This can lead to a Denial of Service (DoS) attack via remote network.
# - CVE-2024-8063: A divide by zero vulnerability exists in ollama/ollama version v0.3.3. The vulnerability occurs
# when importing GGUF models with a crafted type for `block_count` in the Modelfile. This can lead to a denial of
# service (DoS) condition when the server processes the model, causing it to crash.
# - CVE-2024-12886: An Out-Of-Memory (OOM) vulnerability exists in the `ollama` server version 0.3.14. This
# vulnerability can be triggered when a malicious API server responds with a gzip bomb HTTP response, leading to the
# `ollama` server crashing. The vulnerability is present in the `makeRequestWithRetry` and `getAuthorizationToken`
# functions, which use `io.ReadAll` to read the response body. This can result in excessive memory usage and a Denial
# of Service (DoS) condition.
# - CVE-2024-12055: A vulnerability in Ollama versions <=0.3.14 allows a malicious user to create a customized gguf
# model file that can be uploaded to the public Ollama server. When the server processes this malicious model, it
# crashes, leading to a Denial of Service (DoS) attack. The root cause of the issue is an out-of-bounds read in the
# gguf.go file.
# - CVE-2024-39720: Ollama Out-of-bounds Read in github.com/ollama/ollama
# - CVE-2024-39720: An issue was discovered in Ollama before 0.1.46. An attacker can use two HTTP requests to upload
# a malformed GGUF file containing just 4 bytes starting with the GGUF custom magic header. By leveraging a custom
# Modelfile that includes a FROM statement pointing to the attacker-controlled blob file, the attacker can crash the
# application through the CreateModel route, leading to a segmentation fault (signal SIGSEGV: segmentation
# violation).
# - CVE-2024-45436: Ollama can extract members of a ZIP archive outside of the parent directory in
# github.com/ollama/ollama
# [Step 4: Duration 8.15 seconds| Input tokens: 52,465 | Output tokens: 521]
# 'Vulnerabilities in the ollama dependency (Go package manager):\n- CVE-2025-1975: A vulnerability in the Ollama server version 0.5.11 allows a malicious user to cause a Denial of Service (DoS) attack by customizing the manifest content and spoofing a service. This is due to improper validation of array index access when downloading a model via the /api/pull endpoint, which can lead to a server crash.\n- CVE-2024-8063: Ollama Divide by Zero Vulnerability in github.com/ollama/ollama\n- CVE-2025-0312: Ollama Denial of Service (DoS) via Null Pointer Dereference in github.com/ollama/ollama\n- CVE-2024-12886: Ollama Vulnerable to Denial of Service (DoS) via Crafted GZIP in github.com/ollama/ollama\n- CVE-2025-0315: Ollama Allocation of Resources Without Limits or Throttling vulnerability in github.com/ollama/ollama\n- CVE-2024-12055: Ollama Allows Out-of-Bounds Read in github.com/ollama/ollama\n- CVE-2025-0317: Ollama Divide By Zero vulnerability in github.com/ollama/ollama\n- CVE-2025-0317: A vulnerability in ollama/ollama versions <=0.3.14 allows a malicious user to upload and create a customized GGUF model file on the Ollama server. This can lead to a division by zero error in the ggufPadding function, causing the server to crash and resulting in a Denial of Service (DoS) attack.\n- CVE-2025-0315: A vulnerability in ollama/ollama <=0.3.14 allows a malicious user to create a customized GGUF model file, upload it to the Ollama server, and create it. This can cause the server to allocate unlimited memory, leading to a Denial of Service (DoS) attack.\n- CVE-2025-0312: A vulnerability in ollama/ollama versions <=0.3.14 allows a malicious user to create a customized GGUF model file that, when uploaded and created on the Ollama server, can cause a crash due to an unchecked null pointer dereference. This can lead to a Denial of Service (DoS) attack via remote network.\n- CVE-2024-8063: A divide by zero vulnerability exists in ollama/ollama version v0.3.3. The vulnerability occurs when importing GGUF models with a crafted type for `block_count` in the Modelfile. This can lead to a denial of service (DoS) condition when the server processes the model, causing it to crash.\n- CVE-2024-12886: An Out-Of-Memory (OOM) vulnerability exists in the `ollama` server version 0.3.14. This vulnerability can be triggered when a malicious API server responds with a gzip bomb HTTP response, leading to the `ollama` server crashing. The vulnerability is present in the `makeRequestWithRetry` and `getAuthorizationToken` functions, which use `io.ReadAll` to read the response body. This can result in excessive memory usage and a Denial of Service (DoS) condition.\n- CVE-2024-12055: A vulnerability in Ollama versions <=0.3.14 allows a malicious user to create a customized gguf model file that can be uploaded to the public Ollama server. When the server processes this malicious model, it crashes, leading to a Denial of Service (DoS) attack. The root cause of the issue is an out-of-bounds read in the gguf.go file.\n- CVE-2024-39720: Ollama Out-of-bounds Read in github.com/ollama/ollama\n- CVE-2024-39720: An issue was discovered in Ollama before 0.1.46. An attacker can use two HTTP requests to upload a malformed GGUF file containing just 4 bytes starting with the GGUF custom magic header. By leveraging a custom Modelfile that includes a FROM statement pointing to the attacker-controlled blob file, the attacker can crash the application through the CreateModel route, leading to a segmentation fault (signal SIGSEGV: segmentation violation).\n- CVE-2024-45436: Ollama can extract members of a ZIP archive outside of the parent directory in github.com/ollama/ollama\n'

# %% [markdown]
# **`llama-index`** - use case

# %%
from llama_index import *

# %% [markdown]
# **`langgraph`** - use case

# %%
from langgraph import *
